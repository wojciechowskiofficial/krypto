# %% [markdown]
# # test

# %%
import numpy as np
import matplotlib.pyplot as plt
from algo import Encoder, Decoder

# %%
x = plt.imread('unicorn.jpeg')
plt.imshow(x)

# %%
x = Encoder()
message = 'My name is Ozymandias, King of Kings; Look on my Works, ye Mighty, and despair!'
encoded = x.encode(message, plt.imread('unicorn.jpeg'))

# %%
y = Decoder()
y.decode(encoded)
# Out:
# 'My name is Ozymandias, King of Kings; Look on my Works, ye Mighty, and despair!'

# %% [markdown]
# # pytania

# %% [markdown]
# ## 1. Czy	taki	sposób	ukrywania	informacji	w	obrazie	jest	odporny	na	ataki	i	próby zniszczenia	osadzonej	wiadomości.

# %% [markdown]
# ### Nie. Przy jakiejkolwiek kompresji/dekompresji danych lub przy zmianie rozdzielczosci danych obrazowych, które często używają interpolacji wartości pikseli, nawet o 1 pixel tracimy ukrytą wiadomość"

# %% [markdown]
# ## 2. Zaproponuj	ataki	na	osadzoną	wiadomość.

# %% [markdown]
# ### Tak jak w punkcie 1. lub np. losowe filpowanie ostatniego bitu kazdej wartosci RGB wszystkich pikseli na obrazie

# %% [markdown]
# ## 3. Jaki	jest	rozmiar	wiadomości	którą	możemy	ukryć	w	obrazie/pliku	graficznym?

# %% [markdown]
# ### Dla obrazu AxBxC jesteśmy w stanie osadzić wiadomość o długości floor(ABC / 7) - 1 znaków
